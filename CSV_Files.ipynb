# %%
import pandas as pd
from pathlib import Path

# %%
file_path = "Resources/MedianPricesofExistingDetachedHomesHistoricalData.csv"
file_path2 = "Resources/CPI-All-Item-CY"
file_path3 = "Resources/FTB_Housing_Rate"

# %%
median_house_price_df = pd.read_csv(Path(file_path))
median_house_price_df.head(20)
# Out:
#    Median Price (existing single-family detached homes only)   \
# 0                                               *Note
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                              Mon-Yr
# 7                                              Jan-90
# 8                                              Feb-90
# 9                                              Mar-90
# 10                                             Apr-90
# 11                                             May-90
# 12                                             Jun-90
# 13                                             Jul-90
# 14                                             Aug-90
# 15                                             Sep-90
# ...

# %%
median_house_price_df.drop(median_house_price_df.index[range(6)])
# Out:
#     Median Price (existing single-family detached homes only)  Unnamed: 1  \
# 6                                               Mon-Yr                 CA
# 7                                               Jan-90           $194,952
# 8                                               Feb-90           $196,273
# 9                                               Mar-90           $194,856
# 10                                              Apr-90           $196,111
# ..                                                 ...                ...
# 397                                             Jul-22           $833,910
# 398                                             Aug-22           $839,460
# 399                                             Sep-22           $821,680
# 400                                             Oct-22           $801,190
# 401                                             Nov-22           $777,500
#
#      Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5    Unnamed: 6 Unnamed: 7  \
# ...

# %%
median_house_price_df = median_house_price_df.rename(columns=median_house_price_df.iloc[0]).drop(median_house_price_df.index[0])
